# %% [markdown]
# # Untitled
#
# ## Quarto
#
# Quarto enables you to weave together content and executable code into a finished document. To learn more about Quarto see https://quarto.org. BIEP BOEP This is a way to work on notebooks, or quarto docs with peopel who dont know what Git is, and can just contribute as if trough word! I can tracl changes and stream those back to github! @lavaan. Hello. Check it out \[@lavaan \]
#
# ## Running Code
#
# When you click the **Render** button a document will be generated that includes both content and the output of embedded code. You can embed code like this: HOEP HOEP @rothenhausler2015backshift This is some edits I’d like to save

# %%
hist(rnorm(100))

# %% [markdown]
# You can add options to executable code like this

# %%
2 * 2
# Out:
# [1] 4

# %% [markdown]
# The `echo: false` option disables the printing of code (only output is displayed).
